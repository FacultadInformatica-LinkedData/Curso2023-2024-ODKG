# %% [markdown]
# **Task 05: Reading and writing ontologies**

# %%
# !pip install rdflib 
github_storage = "https://raw.githubusercontent.com/FacultadInformatica-LinkedData/Curso2021-2022/master/Assignment4/course_materials"
# Out:
# Requirement already satisfied: rdflib in /Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages (7.0.0)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in /Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages (from rdflib) (0.6.1)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages (from rdflib) (3.1.1)
# Requirement already satisfied: six in /Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# Leemos el fichero RDF de la forma que lo hemos venido haciendo

# %%
from rdflib import Graph, Namespace, Literal
g = Graph()
g.parse(github_storage+"/rdf/example4.rdf", format="xml")
# Out:
# <Graph identifier=Ndbc18d6f687646a992f4b8fe470238e8 (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# Podemos comprobar las ternas que componen el documento de la misma forma.

# %%
for s, p, o in g:
  print(s,p,o)
# Out:
# http://somewhere#Researcher http://www.w3.org/2000/01/rdf-schema#subClassOf http://somewhere#Person
# http://somewhere#JaneSmith http://www.w3.org/2001/vcard-rdf/3.0/Family Smith
# http://somewhere#JaneSmith http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#Person
# http://www.w3.org/2001/vcard-rdf/3.0/Given http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Datatype
# http://xmlns.com/foaf/0.1/knows http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Property
# http://somewhere#Person http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/Family Smith
# http://somewhere#Researcher http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://xmlns.com/foaf/0.1/email http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Datatype
# http://somewhere#JaneSmith http://www.w3.org/2001/vcard-rdf/3.0/FN Jane Smith
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/Given John
# http://www.w3.org/2001/vcard-rdf/3.0/FN http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://www.w3.org/2001/vcard-rdf/3.0/Family http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://www.w3.org/2001/vcard-rdf/3.0/FN http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Datatype
# http://somewhere#JaneSmith http://xmlns.com/foaf/0.1/email jSmith@somewhere.com
# http://xmlns.com/foaf/0.1/email http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://www.w3.org/2001/vcard-rdf/3.0/Family http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Property
# http://somewhere#JaneSmith http://www.w3.org/2001/vcard-rdf/3.0/Given Jane
# http://www.w3.org/2001/vcard-rdf/3.0/Given http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/FN John Smith
# http://somewhere#JohnSmith http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#Person

# %% [markdown]
# También podemos emplear otras herramientas como OntoSPY para visualizar una ontología

# %%
# !pip install ontospy
# Out:
# Requirement already satisfied: ontospy in /Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages (2.1.1)
# Requirement already satisfied: rdflib in /Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages (from ontospy) (7.0.0)
# Requirement already satisfied: SPARQLWrapper in /Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages (from ontospy) (2.0.0)
# Requirement already satisfied: html5lib in /Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages (from ontospy) (1.1)
# Requirement already satisfied: requests in /Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages (from ontospy) (2.31.0)
# Requirement already satisfied: pyfiglet in /Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages (from ontospy) (1.0.2)
# Requirement already satisfied: click in /Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages (from ontospy) (8.1.7)
# Requirement already satisfied: colorama in /Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages (from ontospy) (0.4.6)
# Requirement already satisfied: pyparsing in /Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages (from ontospy) (3.1.1)
# Requirement already satisfied: jinja2 in /Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages (from ontospy) (3.1.2)
# Requirement already satisfied: jinja2-time in /Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages (from ontospy) (0.2.0)
# Requirement already satisfied: pygments in /Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages (from ontospy) (2.16.1)
# Requirement already satisfied: six>=1.9 in /Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages (from html5lib->ontospy) (1.16.0)
# Requirement already satisfied: webencodings in /Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages (from html5lib->ontospy) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages (from jinja2->ontospy) (2.1.3)
# Requirement already satisfied: arrow in /Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages (from jinja2-time->ontospy) (1.2.3)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in /Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages (from rdflib->ontospy) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages (from requests->ontospy) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages (from requests->ontospy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages (from requests->ontospy) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages (from requests->ontospy) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.7.0 in /Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages (from arrow->jinja2-time->ontospy) (2.8.2)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
from ontospy import Ontospy
data = '''

<?xml version="1.0"?>


<!DOCTYPE rdf:RDF [
    <!ENTITY xsd "http://www.w3.org/2001/XMLSchema#" >
    <!ENTITY rdfs "http://www.w3.org/2000/01/rdf-schema#" >
    <!ENTITY rdf "http://www.w3.org/1999/02/22-rdf-syntax-ns#" >
    <!ENTITY example4 "http://www.sowhere.com#" >
    <!ENTITY foaf "http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/" >
    <!ENTITY vcard-rdf "http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/" >
]>


<rdf:RDF xmlns="http://www.sowhere.com#"
     xml:base="http://www.sowhere.com"
     xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
     xmlns:foaf="&example4;http://xmlns.com/foaf/0.1/"
     xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
     xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
     xmlns:vcard-rdf="&example4;http://www.w3.org/2001/vcard-rdf/3.0/"
     xmlns:example4="http://www.semanticweb.org/ontologies/example4.rdf#">
    


    <!-- 
    ///////////////////////////////////////////////////////////////////////////////////////
    //
    // Object Properties
    //
    ///////////////////////////////////////////////////////////////////////////////////////
     -->

    


    <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/knows -->

    <rdf:Property rdf:about="#http://xmlns.com/foaf/0.1/knows"/>
    


    <!-- 
    ///////////////////////////////////////////////////////////////////////////////////////
    //
    // Data properties
    //
    ///////////////////////////////////////////////////////////////////////////////////////
     -->

    


    <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/FN -->

    <rdfs:Datatype rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/FN">
        <rdfs:range rdf:resource="&xsd;string"/>
    </rdfs:Datatype>
    


    <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Family -->

    <rdf:Property rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/Family">
        <rdfs:domain rdf:resource="#Person"/>
        <rdfs:range rdf:resource="&xsd;string"/>
    </rdf:Property>
    


    <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Given -->

    <rdfs:Datatype rdf:about="#http://www.w3.org/2001/vcard-rdf/3.0/Given">
        <rdfs:domain rdf:resource="#Person"/>
        <rdfs:range rdf:resource="&xsd;string"/>
    </rdfs:Datatype>
    


    <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/email -->

    <rdfs:Datatype rdf:about="#http://xmlns.com/foaf/0.1/email">
        <rdfs:domain rdf:resource="#Person"/>
        <rdfs:range rdf:resource="&xsd;string"/>
    </rdfs:Datatype>
    


    <!-- 
    ///////////////////////////////////////////////////////////////////////////////////////
    //
    // Classes
    //
    ///////////////////////////////////////////////////////////////////////////////////////
     -->

    


    <!-- http://www.semanticweb.org/ontologies/example4.rdf#Person -->

    <rdfs:Class rdf:about="#Person"/>
    


    <!-- http://www.semanticweb.org/ontologies/example4.rdf#Researcher -->

    <rdfs:Class rdf:about="#Researcher">
        <rdfs:subClassOf rdf:resource="#Person"/>
    </rdfs:Class>
    


    <!-- 
    ///////////////////////////////////////////////////////////////////////////////////////
    //
    // Individuals
    //
    ///////////////////////////////////////////////////////////////////////////////////////
     -->

    


    <!-- http://www.semanticweb.org/ontologies/example4.rdf#JaneSmith -->

    <Person rdf:about="#JaneSmith">
        <vcard-rdf:Given rdf:datatype="&xsd;string">Jane</vcard-rdf:Given>
        <vcard-rdf:FN rdf:datatype="&xsd;string">Jane Smith</vcard-rdf:FN>
        <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>
        <foaf:email rdf:datatype="&xsd;string"
            >jSmith@somewhere.com</foaf:email>
    </Person>
    


    <!-- http://www.semanticweb.org/ontologies/example4.rdf#JohnSmith -->

    <Person rdf:about="#JohnSmith">
        <vcard-rdf:Given rdf:datatype="&xsd;string">John</vcard-rdf:Given>
        <vcard-rdf:FN rdf:datatype="&xsd;string">John Smith</vcard-rdf:FN>
        <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>
    </Person>
</rdf:RDF>



<!-- Generated by the OWL API (version 2.2.1.1138) http://owlapi.sourceforge.net -->



'''

model = Ontospy(data, verbose=True)
print(model.all_classes)
print(model.all_properties)
# Out:
# Reading: <
#
# <?xml version="1.0"?>
#
#
# <!DOCTYPE rdf:RDF [
#     <!ENTITY xsd "http://www.w3.org/2001/XMLSchema#" >
#     <!ENTITY rdfs "http://www.w3.org/2000/01/rdf-schema#" >
#     <!ENTITY rdf "http://www.w3.org/1999/02/22-rdf-syntax-ns#" >
#     <!ENTITY example4 "http://www.sowhere.com#" >
#     <!ENTITY foaf "http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/" >
#     <!ENTITY vcard-rdf "http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/" >
# ]>
#
#
# <rdf:RDF xmlns="http://www.sowhere.com#"
#      xml:base="http://www.sowhere.com"
#      xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#      xmlns:foaf="&example4;http://xmlns.com/foaf/0.1/"
#      xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#      xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#      xmlns:vcard-rdf="&example4;http://www.w3.org/2001/vcard-rdf/3.0/"
#      xmlns:example4="http://www.semanticweb.org/ontologies/example4.rdf#">
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Object Properties
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/knows -->
#
#     <rdf:Property rdf:about="#http://xmlns.com/foaf/0.1/knows"/>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Data properties
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/FN -->
#
#     <rdfs:Datatype rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/FN">
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Family -->
#
#     <rdf:Property rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/Family">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdf:Property>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Given -->
#
#     <rdfs:Datatype rdf:about="#http://www.w3.org/2001/vcard-rdf/3.0/Given">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/email -->
#
#     <rdfs:Datatype rdf:about="#http://xmlns.com/foaf/0.1/email">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Classes
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#Person -->
#
#     <rdfs:Class rdf:about="#Person"/>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#Researcher -->
#
#     <rdfs:Class rdf:about="#Researcher">
#         <rdfs:subClassOf rdf:resource="#Person"/>
#     </rdfs:Class>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Individuals
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#JaneSmith -->
#
#     <Person rdf:about="#JaneSmith">
#         <vcard-rdf:Given rdf:datatype="&xsd;string">Jane</vcard-rdf:Given>
#         <vcard-rdf:FN rdf:datatype="&xsd;string">Jane Smith</vcard-rdf:FN>
#         <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>
#         <foaf:email rdf:datatype="&xsd;string"
#             >jSmith@somewhere.com</foaf:email>
#     </Person>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#JohnSmith -->
#
#     <Person rdf:about="#JohnSmith">
#         <vcard-rdf:Given rdf:datatype="&xsd;string">John</vcard-rdf:Given>
#         <vcard-rdf:FN rdf:datatype="&xsd;string">John Smith</vcard-rdf:FN>
#         <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>
#     </Person>
# </rdf:RDF>
#
#
#
# <!-- Generated by the OWL API (version 2.2.1.1138) http://owlapi.sourceforge.net -->
#
#
#
# >
# .. trying rdf serialization: <xml>
# WARNING:rdflib.term:file:///Users/cesarpantoja/Documents/Master%20de%20ciencie%20de%20datos%20en%20medicina/023-2024-ODKG/Curso2023-2024-ODKG/Assignment4/course_materials/<?xml version="1.0"?><!DOCTYPE rdf:RDF [    <!ENTITY xsd "http://www.w3.org/2001/XMLSchema#" >    <!ENTITY rdfs "http://www.w3.org/2000/01/rdf-schema#" >    <!ENTITY rdf "http://www.w3.org/1999/02/22-rdf-syntax-ns#" >    <!ENTITY example4 "http://www.sowhere.com#" >    <!ENTITY foaf "http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/" >    <!ENTITY vcard-rdf "http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/" >]><rdf:RDF xmlns="http://www.sowhere.com#"     xml:base="http://www.sowhere.com"     xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"     xmlns:foaf="&example4;http://xmlns.com/foaf/0.1/"     xmlns:xsd="http://www.w3.org/2001/XMLSchema#"     xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"     xmlns:vcard-rdf="&example4;http://www.w3.org/2001/vcard-rdf/3.0/"     xmlns:example4="http://www.semanticweb.org/ontologies/example4.rdf#">        <!--     ///////////////////////////////////////////////////////////////////////////////////////    //    // Object Properties    //    ///////////////////////////////////////////////////////////////////////////////////////     -->        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/knows -->    <rdf:Property rdf:about="#http://xmlns.com/foaf/0.1/knows"/>        <!--     ///////////////////////////////////////////////////////////////////////////////////////    //    // Data properties    //    ///////////////////////////////////////////////////////////////////////////////////////     -->        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/FN -->    <rdfs:Datatype rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/FN">        <rdfs:range rdf:resource="&xsd;string"/>    </rdfs:Datatype>        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Family -->    <rdf:Property rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/Family">        <rdfs:domain rdf:resource="#Person"/>        <rdfs:range rdf:resource="&xsd;string"/>    </rdf:Property>        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Given -->    <rdfs:Datatype rdf:about="#http://www.w3.org/2001/vcard-rdf/3.0/Given">        <rdfs:domain rdf:resource="#Person"/>        <rdfs:range rdf:resource="&xsd;string"/>    </rdfs:Datatype>        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/email -->    <rdfs:Datatype rdf:about="#http://xmlns.com/foaf/0.1/email">        <rdfs:domain rdf:resource="#Person"/>        <rdfs:range rdf:resource="&xsd;string"/>    </rdfs:Datatype>        <!--     ///////////////////////////////////////////////////////////////////////////////////////    //    // Classes    //    ///////////////////////////////////////////////////////////////////////////////////////     -->        <!-- http://www.semanticweb.org/ontologies/example4.rdf#Person -->    <rdfs:Class rdf:about="#Person"/>        <!-- http://www.semanticweb.org/ontologies/example4.rdf#Researcher -->    <rdfs:Class rdf:about="#Researcher">        <rdfs:subClassOf rdf:resource="#Person"/>    </rdfs:Class>        <!--     ///////////////////////////////////////////////////////////////////////////////////////    //    // Individuals    //    ///////////////////////////////////////////////////////////////////////////////////////     -->        <!-- http://www.semanticweb.org/ontologies/example4.rdf#JaneSmith -->    <Person rdf:about="#JaneSmith">        <vcard-rdf:Given rdf:datatype="&xsd;string">Jane</vcard-rdf:Given>        <vcard-rdf:FN rdf:datatype="&xsd;string">Jane Smith</vcard-rdf:FN>        <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>        <foaf:email rdf:datatype="&xsd;string"           ...
# ..... failed
# .. trying rdf serialization: <n3>
# WARNING:rdflib.term:file:///Users/cesarpantoja/Documents/Master%20de%20ciencie%20de%20datos%20en%20medicina/023-2024-ODKG/Curso2023-2024-ODKG/Assignment4/course_materials/<?xml version="1.0"?><!DOCTYPE rdf:RDF [    <!ENTITY xsd "http://www.w3.org/2001/XMLSchema#" >    <!ENTITY rdfs "http://www.w3.org/2000/01/rdf-schema#" >    <!ENTITY rdf "http://www.w3.org/1999/02/22-rdf-syntax-ns#" >    <!ENTITY example4 "http://www.sowhere.com#" >    <!ENTITY foaf "http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/" >    <!ENTITY vcard-rdf "http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/" >]><rdf:RDF xmlns="http://www.sowhere.com#"     xml:base="http://www.sowhere.com"     xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"     xmlns:foaf="&example4;http://xmlns.com/foaf/0.1/"     xmlns:xsd="http://www.w3.org/2001/XMLSchema#"     xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"     xmlns:vcard-rdf="&example4;http://www.w3.org/2001/vcard-rdf/3.0/"     xmlns:example4="http://www.semanticweb.org/ontologies/example4.rdf#">        <!--     ///////////////////////////////////////////////////////////////////////////////////////    //    // Object Properties    //    ///////////////////////////////////////////////////////////////////////////////////////     -->        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/knows -->    <rdf:Property rdf:about="#http://xmlns.com/foaf/0.1/knows"/>        <!--     ///////////////////////////////////////////////////////////////////////////////////////    //    // Data properties    //    ///////////////////////////////////////////////////////////////////////////////////////     -->        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/FN -->    <rdfs:Datatype rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/FN">        <rdfs:range rdf:resource="&xsd;string"/>    </rdfs:Datatype>        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Family -->    <rdf:Property rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/Family">        <rdfs:domain rdf:resource="#Person"/>        <rdfs:range rdf:resource="&xsd;string"/>    </rdf:Property>        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Given -->    <rdfs:Datatype rdf:about="#http://www.w3.org/2001/vcard-rdf/3.0/Given">        <rdfs:domain rdf:resource="#Person"/>        <rdfs:range rdf:resource="&xsd;string"/>    </rdfs:Datatype>        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/email -->    <rdfs:Datatype rdf:about="#http://xmlns.com/foaf/0.1/email">        <rdfs:domain rdf:resource="#Person"/>        <rdfs:range rdf:resource="&xsd;string"/>    </rdfs:Datatype>        <!--     ///////////////////////////////////////////////////////////////////////////////////////    //    // Classes    //    ///////////////////////////////////////////////////////////////////////////////////////     -->        <!-- http://www.semanticweb.org/ontologies/example4.rdf#Person -->    <rdfs:Class rdf:about="#Person"/>        <!-- http://www.semanticweb.org/ontologies/example4.rdf#Researcher -->    <rdfs:Class rdf:about="#Researcher">        <rdfs:subClassOf rdf:resource="#Person"/>    </rdfs:Class>        <!--     ///////////////////////////////////////////////////////////////////////////////////////    //    // Individuals    //    ///////////////////////////////////////////////////////////////////////////////////////     -->        <!-- http://www.semanticweb.org/ontologies/example4.rdf#JaneSmith -->    <Person rdf:about="#JaneSmith">        <vcard-rdf:Given rdf:datatype="&xsd;string">Jane</vcard-rdf:Given>        <vcard-rdf:FN rdf:datatype="&xsd;string">Jane Smith</vcard-rdf:FN>        <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>        <foaf:email rdf:datatype="&xsd;string"           ...
# ..... failed
# .. trying rdf serialization: <nt>
# WARNING:rdflib.term:file:///Users/cesarpantoja/Documents/Master%20de%20ciencie%20de%20datos%20en%20medicina/023-2024-ODKG/Curso2023-2024-ODKG/Assignment4/course_materials/<?xml version="1.0"?><!DOCTYPE rdf:RDF [    <!ENTITY xsd "http://www.w3.org/2001/XMLSchema#" >    <!ENTITY rdfs "http://www.w3.org/2000/01/rdf-schema#" >    <!ENTITY rdf "http://www.w3.org/1999/02/22-rdf-syntax-ns#" >    <!ENTITY example4 "http://www.sowhere.com#" >    <!ENTITY foaf "http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/" >    <!ENTITY vcard-rdf "http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/" >]><rdf:RDF xmlns="http://www.sowhere.com#"     xml:base="http://www.sowhere.com"     xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"     xmlns:foaf="&example4;http://xmlns.com/foaf/0.1/"     xmlns:xsd="http://www.w3.org/2001/XMLSchema#"     xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"     xmlns:vcard-rdf="&example4;http://www.w3.org/2001/vcard-rdf/3.0/"     xmlns:example4="http://www.semanticweb.org/ontologies/example4.rdf#">        <!--     ///////////////////////////////////////////////////////////////////////////////////////    //    // Object Properties    //    ///////////////////////////////////////////////////////////////////////////////////////     -->        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/knows -->    <rdf:Property rdf:about="#http://xmlns.com/foaf/0.1/knows"/>        <!--     ///////////////////////////////////////////////////////////////////////////////////////    //    // Data properties    //    ///////////////////////////////////////////////////////////////////////////////////////     -->        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/FN -->    <rdfs:Datatype rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/FN">        <rdfs:range rdf:resource="&xsd;string"/>    </rdfs:Datatype>        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Family -->    <rdf:Property rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/Family">        <rdfs:domain rdf:resource="#Person"/>        <rdfs:range rdf:resource="&xsd;string"/>    </rdf:Property>        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Given -->    <rdfs:Datatype rdf:about="#http://www.w3.org/2001/vcard-rdf/3.0/Given">        <rdfs:domain rdf:resource="#Person"/>        <rdfs:range rdf:resource="&xsd;string"/>    </rdfs:Datatype>        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/email -->    <rdfs:Datatype rdf:about="#http://xmlns.com/foaf/0.1/email">        <rdfs:domain rdf:resource="#Person"/>        <rdfs:range rdf:resource="&xsd;string"/>    </rdfs:Datatype>        <!--     ///////////////////////////////////////////////////////////////////////////////////////    //    // Classes    //    ///////////////////////////////////////////////////////////////////////////////////////     -->        <!-- http://www.semanticweb.org/ontologies/example4.rdf#Person -->    <rdfs:Class rdf:about="#Person"/>        <!-- http://www.semanticweb.org/ontologies/example4.rdf#Researcher -->    <rdfs:Class rdf:about="#Researcher">        <rdfs:subClassOf rdf:resource="#Person"/>    </rdfs:Class>        <!--     ///////////////////////////////////////////////////////////////////////////////////////    //    // Individuals    //    ///////////////////////////////////////////////////////////////////////////////////////     -->        <!-- http://www.semanticweb.org/ontologies/example4.rdf#JaneSmith -->    <Person rdf:about="#JaneSmith">        <vcard-rdf:Given rdf:datatype="&xsd;string">Jane</vcard-rdf:Given>        <vcard-rdf:FN rdf:datatype="&xsd;string">Jane Smith</vcard-rdf:FN>        <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>        <foaf:email rdf:datatype="&xsd;string"           ...
# ..... failed
# .. trying rdf serialization: <json-ld>
# Detected JSONLD - loading data into rdflib.ConjunctiveGraph()
# WARNING:rdflib.term:file:///Users/cesarpantoja/Documents/Master%20de%20ciencie%20de%20datos%20en%20medicina/023-2024-ODKG/Curso2023-2024-ODKG/Assignment4/course_materials/<?xml version="1.0"?><!DOCTYPE rdf:RDF [    <!ENTITY xsd "http://www.w3.org/2001/XMLSchema#" >    <!ENTITY rdfs "http://www.w3.org/2000/01/rdf-schema#" >    <!ENTITY rdf "http://www.w3.org/1999/02/22-rdf-syntax-ns#" >    <!ENTITY example4 "http://www.sowhere.com#" >    <!ENTITY foaf "http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/" >    <!ENTITY vcard-rdf "http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/" >]><rdf:RDF xmlns="http://www.sowhere.com#"     xml:base="http://www.sowhere.com"     xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"     xmlns:foaf="&example4;http://xmlns.com/foaf/0.1/"     xmlns:xsd="http://www.w3.org/2001/XMLSchema#"     xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"     xmlns:vcard-rdf="&example4;http://www.w3.org/2001/vcard-rdf/3.0/"     xmlns:example4="http://www.semanticweb.org/ontologies/example4.rdf#">        <!--     ///////////////////////////////////////////////////////////////////////////////////////    //    // Object Properties    //    ///////////////////////////////////////////////////////////////////////////////////////     -->        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/knows -->    <rdf:Property rdf:about="#http://xmlns.com/foaf/0.1/knows"/>        <!--     ///////////////////////////////////////////////////////////////////////////////////////    //    // Data properties    //    ///////////////////////////////////////////////////////////////////////////////////////     -->        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/FN -->    <rdfs:Datatype rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/FN">        <rdfs:range rdf:resource="&xsd;string"/>    </rdfs:Datatype>        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Family -->    <rdf:Property rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/Family">        <rdfs:domain rdf:resource="#Person"/>        <rdfs:range rdf:resource="&xsd;string"/>    </rdf:Property>        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Given -->    <rdfs:Datatype rdf:about="#http://www.w3.org/2001/vcard-rdf/3.0/Given">        <rdfs:domain rdf:resource="#Person"/>        <rdfs:range rdf:resource="&xsd;string"/>    </rdfs:Datatype>        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/email -->    <rdfs:Datatype rdf:about="#http://xmlns.com/foaf/0.1/email">        <rdfs:domain rdf:resource="#Person"/>        <rdfs:range rdf:resource="&xsd;string"/>    </rdfs:Datatype>        <!--     ///////////////////////////////////////////////////////////////////////////////////////    //    // Classes    //    ///////////////////////////////////////////////////////////////////////////////////////     -->        <!-- http://www.semanticweb.org/ontologies/example4.rdf#Person -->    <rdfs:Class rdf:about="#Person"/>        <!-- http://www.semanticweb.org/ontologies/example4.rdf#Researcher -->    <rdfs:Class rdf:about="#Researcher">        <rdfs:subClassOf rdf:resource="#Person"/>    </rdfs:Class>        <!--     ///////////////////////////////////////////////////////////////////////////////////////    //    // Individuals    //    ///////////////////////////////////////////////////////////////////////////////////////     -->        <!-- http://www.semanticweb.org/ontologies/example4.rdf#JaneSmith -->    <Person rdf:about="#JaneSmith">        <vcard-rdf:Given rdf:datatype="&xsd;string">Jane</vcard-rdf:Given>        <vcard-rdf:FN rdf:datatype="&xsd;string">Jane Smith</vcard-rdf:FN>        <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>        <foaf:email rdf:datatype="&xsd;string"           ...
# ..... failed
# .. trying rdf serialization: <turtle>
# WARNING:rdflib.term:file:///Users/cesarpantoja/Documents/Master%20de%20ciencie%20de%20datos%20en%20medicina/023-2024-ODKG/Curso2023-2024-ODKG/Assignment4/course_materials/<?xml version="1.0"?><!DOCTYPE rdf:RDF [    <!ENTITY xsd "http://www.w3.org/2001/XMLSchema#" >    <!ENTITY rdfs "http://www.w3.org/2000/01/rdf-schema#" >    <!ENTITY rdf "http://www.w3.org/1999/02/22-rdf-syntax-ns#" >    <!ENTITY example4 "http://www.sowhere.com#" >    <!ENTITY foaf "http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/" >    <!ENTITY vcard-rdf "http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/" >]><rdf:RDF xmlns="http://www.sowhere.com#"     xml:base="http://www.sowhere.com"     xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"     xmlns:foaf="&example4;http://xmlns.com/foaf/0.1/"     xmlns:xsd="http://www.w3.org/2001/XMLSchema#"     xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"     xmlns:vcard-rdf="&example4;http://www.w3.org/2001/vcard-rdf/3.0/"     xmlns:example4="http://www.semanticweb.org/ontologies/example4.rdf#">        <!--     ///////////////////////////////////////////////////////////////////////////////////////    //    // Object Properties    //    ///////////////////////////////////////////////////////////////////////////////////////     -->        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/knows -->    <rdf:Property rdf:about="#http://xmlns.com/foaf/0.1/knows"/>        <!--     ///////////////////////////////////////////////////////////////////////////////////////    //    // Data properties    //    ///////////////////////////////////////////////////////////////////////////////////////     -->        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/FN -->    <rdfs:Datatype rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/FN">        <rdfs:range rdf:resource="&xsd;string"/>    </rdfs:Datatype>        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Family -->    <rdf:Property rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/Family">        <rdfs:domain rdf:resource="#Person"/>        <rdfs:range rdf:resource="&xsd;string"/>    </rdf:Property>        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Given -->    <rdfs:Datatype rdf:about="#http://www.w3.org/2001/vcard-rdf/3.0/Given">        <rdfs:domain rdf:resource="#Person"/>        <rdfs:range rdf:resource="&xsd;string"/>    </rdfs:Datatype>        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/email -->    <rdfs:Datatype rdf:about="#http://xmlns.com/foaf/0.1/email">        <rdfs:domain rdf:resource="#Person"/>        <rdfs:range rdf:resource="&xsd;string"/>    </rdfs:Datatype>        <!--     ///////////////////////////////////////////////////////////////////////////////////////    //    // Classes    //    ///////////////////////////////////////////////////////////////////////////////////////     -->        <!-- http://www.semanticweb.org/ontologies/example4.rdf#Person -->    <rdfs:Class rdf:about="#Person"/>        <!-- http://www.semanticweb.org/ontologies/example4.rdf#Researcher -->    <rdfs:Class rdf:about="#Researcher">        <rdfs:subClassOf rdf:resource="#Person"/>    </rdfs:Class>        <!--     ///////////////////////////////////////////////////////////////////////////////////////    //    // Individuals    //    ///////////////////////////////////////////////////////////////////////////////////////     -->        <!-- http://www.semanticweb.org/ontologies/example4.rdf#JaneSmith -->    <Person rdf:about="#JaneSmith">        <vcard-rdf:Given rdf:datatype="&xsd;string">Jane</vcard-rdf:Given>        <vcard-rdf:FN rdf:datatype="&xsd;string">Jane Smith</vcard-rdf:FN>        <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>        <foaf:email rdf:datatype="&xsd;string"           ...
# ..... failed
# .. trying rdf serialization: <rdfa>
# WARNING:rdflib.term:file:///Users/cesarpantoja/Documents/Master%20de%20ciencie%20de%20datos%20en%20medicina/023-2024-ODKG/Curso2023-2024-ODKG/Assignment4/course_materials/<?xml version="1.0"?><!DOCTYPE rdf:RDF [    <!ENTITY xsd "http://www.w3.org/2001/XMLSchema#" >    <!ENTITY rdfs "http://www.w3.org/2000/01/rdf-schema#" >    <!ENTITY rdf "http://www.w3.org/1999/02/22-rdf-syntax-ns#" >    <!ENTITY example4 "http://www.sowhere.com#" >    <!ENTITY foaf "http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/" >    <!ENTITY vcard-rdf "http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/" >]><rdf:RDF xmlns="http://www.sowhere.com#"     xml:base="http://www.sowhere.com"     xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"     xmlns:foaf="&example4;http://xmlns.com/foaf/0.1/"     xmlns:xsd="http://www.w3.org/2001/XMLSchema#"     xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"     xmlns:vcard-rdf="&example4;http://www.w3.org/2001/vcard-rdf/3.0/"     xmlns:example4="http://www.semanticweb.org/ontologies/example4.rdf#">        <!--     ///////////////////////////////////////////////////////////////////////////////////////    //    // Object Properties    //    ///////////////////////////////////////////////////////////////////////////////////////     -->        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/knows -->    <rdf:Property rdf:about="#http://xmlns.com/foaf/0.1/knows"/>        <!--     ///////////////////////////////////////////////////////////////////////////////////////    //    // Data properties    //    ///////////////////////////////////////////////////////////////////////////////////////     -->        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/FN -->    <rdfs:Datatype rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/FN">        <rdfs:range rdf:resource="&xsd;string"/>    </rdfs:Datatype>        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Family -->    <rdf:Property rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/Family">        <rdfs:domain rdf:resource="#Person"/>        <rdfs:range rdf:resource="&xsd;string"/>    </rdf:Property>        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Given -->    <rdfs:Datatype rdf:about="#http://www.w3.org/2001/vcard-rdf/3.0/Given">        <rdfs:domain rdf:resource="#Person"/>        <rdfs:range rdf:resource="&xsd;string"/>    </rdfs:Datatype>        <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/email -->    <rdfs:Datatype rdf:about="#http://xmlns.com/foaf/0.1/email">        <rdfs:domain rdf:resource="#Person"/>        <rdfs:range rdf:resource="&xsd;string"/>    </rdfs:Datatype>        <!--     ///////////////////////////////////////////////////////////////////////////////////////    //    // Classes    //    ///////////////////////////////////////////////////////////////////////////////////////     -->        <!-- http://www.semanticweb.org/ontologies/example4.rdf#Person -->    <rdfs:Class rdf:about="#Person"/>        <!-- http://www.semanticweb.org/ontologies/example4.rdf#Researcher -->    <rdfs:Class rdf:about="#Researcher">        <rdfs:subClassOf rdf:resource="#Person"/>    </rdfs:Class>        <!--     ///////////////////////////////////////////////////////////////////////////////////////    //    // Individuals    //    ///////////////////////////////////////////////////////////////////////////////////////     -->        <!-- http://www.semanticweb.org/ontologies/example4.rdf#JaneSmith -->    <Person rdf:about="#JaneSmith">        <vcard-rdf:Given rdf:datatype="&xsd;string">Jane</vcard-rdf:Given>        <vcard-rdf:FN rdf:datatype="&xsd;string">Jane Smith</vcard-rdf:FN>        <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>        <foaf:email rdf:datatype="&xsd;string"           ...
# ..... failed
# ----------
# Fatal error parsing graph <
#
# <?xml version="1.0"?>
#
#
# <!DOCTYPE rdf:RDF [
#     <!ENTITY xsd "http://www.w3.org/2001/XMLSchema#" >
#     <!ENTITY rdfs "http://www.w3.org/2000/01/rdf-schema#" >
#     <!ENTITY rdf "http://www.w3.org/1999/02/22-rdf-syntax-ns#" >
#     <!ENTITY example4 "http://www.sowhere.com#" >
#     <!ENTITY foaf "http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/" >
#     <!ENTITY vcard-rdf "http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/" >
# ]>
#
#
# <rdf:RDF xmlns="http://www.sowhere.com#"
#      xml:base="http://www.sowhere.com"
#      xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#      xmlns:foaf="&example4;http://xmlns.com/foaf/0.1/"
#      xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#      xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#      xmlns:vcard-rdf="&example4;http://www.w3.org/2001/vcard-rdf/3.0/"
#      xmlns:example4="http://www.semanticweb.org/ontologies/example4.rdf#">
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Object Properties
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/knows -->
#
#     <rdf:Property rdf:about="#http://xmlns.com/foaf/0.1/knows"/>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Data properties
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/FN -->
#
#     <rdfs:Datatype rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/FN">
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Family -->
#
#     <rdf:Property rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/Family">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdf:Property>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Given -->
#
#     <rdfs:Datatype rdf:about="#http://www.w3.org/2001/vcard-rdf/3.0/Given">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/email -->
#
#     <rdfs:Datatype rdf:about="#http://xmlns.com/foaf/0.1/email">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Classes
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#Person -->
#
#     <rdfs:Class rdf:about="#Person"/>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#Researcher -->
#
#     <rdfs:Class rdf:about="#Researcher">
#         <rdfs:subClassOf rdf:resource="#Person"/>
#     </rdfs:Class>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Individuals
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#JaneSmith -->
#
#     <Person rdf:about="#JaneSmith">
#         <vcard-rdf:Given rdf:datatype="&xsd;string">Jane</vcard-rdf:Given>
#         <vcard-rdf:FN rdf:datatype="&xsd;string">Jane Smith</vcard-rdf:FN>
#         <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>
#         <foaf:email rdf:datatype="&xsd;string"
#             >jSmith@somewhere.com</foaf:email>
#     </Person>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#JohnSmith -->
#
#     <Person rdf:about="#JohnSmith">
#         <vcard-rdf:Given rdf:datatype="&xsd;string">John</vcard-rdf:Given>
#         <vcard-rdf:FN rdf:datatype="&xsd;string">John Smith</vcard-rdf:FN>
#         <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>
#     </Person>
# </rdf:RDF>
#
#
#
# <!-- Generated by the OWL API (version 2.2.1.1138) http://owlapi.sourceforge.net -->
#
#
#
# >
# (tried RDF serializations: ['xml', 'n3', 'nt', 'json-ld', 'turtle', 'rdfa'])
# ----------
# TIP: You can try one of the following RDF validation services
# <http://mowl-power.cs.man.ac.uk:8080/validator/validate>
# <http://rdfvalidator.mybluemix.net/>
# <https://json-ld.org/playground/>
# Sorry - no valid RDF was found
# ----------
# RDF sources failed to load: 1.
# ----------
# ->
#
# <?xml version="1.0"?>
#
#
# <!DOCTYPE rdf:RDF [
#     <!ENTITY xsd "http://www.w3.org/2001/XMLSchema#" >
#     <!ENTITY rdfs "http://www.w3.org/2000/01/rdf-schema#" >
#     <!ENTITY rdf "http://www.w3.org/1999/02/22-rdf-syntax-ns#" >
#     <!ENTITY example4 "http://www.sowhere.com#" >
#     <!ENTITY foaf "http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/" >
#     <!ENTITY vcard-rdf "http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/" >
# ]>
#
#
# <rdf:RDF xmlns="http://www.sowhere.com#"
#      xml:base="http://www.sowhere.com"
#      xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#      xmlns:foaf="&example4;http://xmlns.com/foaf/0.1/"
#      xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
#      xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#      xmlns:vcard-rdf="&example4;http://www.w3.org/2001/vcard-rdf/3.0/"
#      xmlns:example4="http://www.semanticweb.org/ontologies/example4.rdf#">
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Object Properties
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/knows -->
#
#     <rdf:Property rdf:about="#http://xmlns.com/foaf/0.1/knows"/>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Data properties
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/FN -->
#
#     <rdfs:Datatype rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/FN">
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Family -->
#
#     <rdf:Property rdf:about="http://www.w3.org/2001/vcard-rdf/3.0/Family">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdf:Property>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://www.w3.org/2001/vcard-rdf/3.0/Given -->
#
#     <rdfs:Datatype rdf:about="#http://www.w3.org/2001/vcard-rdf/3.0/Given">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#http://xmlns.com/foaf/0.1/email -->
#
#     <rdfs:Datatype rdf:about="#http://xmlns.com/foaf/0.1/email">
#         <rdfs:domain rdf:resource="#Person"/>
#         <rdfs:range rdf:resource="&xsd;string"/>
#     </rdfs:Datatype>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Classes
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#Person -->
#
#     <rdfs:Class rdf:about="#Person"/>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#Researcher -->
#
#     <rdfs:Class rdf:about="#Researcher">
#         <rdfs:subClassOf rdf:resource="#Person"/>
#     </rdfs:Class>
#
#
#
#     <!--
#     ///////////////////////////////////////////////////////////////////////////////////////
#     //
#     // Individuals
#     //
#     ///////////////////////////////////////////////////////////////////////////////////////
#      -->
#
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#JaneSmith -->
#
#     <Person rdf:about="#JaneSmith">
#         <vcard-rdf:Given rdf:datatype="&xsd;string">Jane</vcard-rdf:Given>
#         <vcard-rdf:FN rdf:datatype="&xsd;string">Jane Smith</vcard-rdf:FN>
#         <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>
#         <foaf:email rdf:datatype="&xsd;string"
#             >jSmith@somewhere.com</foaf:email>
#     </Person>
#
#
#
#     <!-- http://www.semanticweb.org/ontologies/example4.rdf#JohnSmith -->
#
#     <Person rdf:about="#JohnSmith">
#         <vcard-rdf:Given rdf:datatype="&xsd;string">John</vcard-rdf:Given>
#         <vcard-rdf:FN rdf:datatype="&xsd;string">John Smith</vcard-rdf:FN>
#         <vcard-rdf:Family rdf:datatype="&xsd;string">Smith</vcard-rdf:Family>
#     </Person>
# </rdf:RDF>
#
#
#
# <!-- Generated by the OWL API (version 2.2.1.1138) http://owlapi.sourceforge.net -->
# Scanning entities...
# ----------
# Ontologies.........: 0
# Classes............: 0
# Properties.........: 0
# ..annotation.......: 0
# ..datatype.........: 0
# ..object...........: 0
# Concepts (SKOS)....: 0
# Shapes (SHACL).....: 0
# ----------
# []
# []
