# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# First, we load the updated data set

# %%
#Analyse both the data (quantities, value ranges, etc.) as well as the schema of the data.
path = '../csv/desfibriladores-updated_v2.csv'
df = pd.read_csv(path, sep = ";", encoding = "utf8", dtype = str)
df = df.astype({"direccion_coordenada_x":float, "direccion_coordenada_y":float})
df
# Out:
#                                    tipo_establecimiento tipo_titularidad  \
# 0     Establecimiento dependiente de una Administrac...          Pública
# 1                                                 Otros          Privada
# 2         Centro de trabajo con más de 250 trabajadores          Privada
# 3                                      Centro educativo          Privada
# 4     Establecimiento dependiente de una Administrac...          Pública
# ...                                                 ...              ...
# 9150  Establecimiento dependiente de una Administrac...          Pública
# 9151                                              Otros          Privada
# 9152                                              Otros          Privada
# 9153                                              Otros          Privada
# 9154                                              Otros          Privada
#
#      municipio_codigo    municipio_nombre  \
# 0                 079              Madrid
# ...

# %% [markdown]
# We check how many different values are present in each attribute

# %%
for attribute in df:
    print(f'The attribute "{attribute}" has {str(len(df[attribute].unique()))} different values')
# Out:
# The attribute "tipo_establecimiento" has 11 different values
# The attribute "tipo_titularidad" has 2 different values
# The attribute "municipio_codigo" has 155 different values
# The attribute "municipio_nombre" has 156 different values
# The attribute "Municipio URIs" has 156 different values
# The attribute "direccion_via_codigo" has 6923 different values
# The attribute "direccion_codigo_postal" has 258 different values
# The attribute "direccion_ubicacion" has 6198 different values
# The attribute "direccion_coordenada_x" has 6176 different values
# The attribute "direccion_coordenada_y" has 6286 different values
# The attribute "horario_acceso" has 1630 different values
# The attribute "codigo_dea" has 9141 different values

# %%
sns.set(font_scale=1)
fig, (ax1) = plt.subplots(nrows = 1, ncols = 1, figsize = (5,3))
sns.countplot(df, x = df.tipo_titularidad, ax = ax1)
ax1.set(title = "Titularity type")
plt.show()
# Out:
# /home/javi/miniconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/javi/miniconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/javi/miniconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.set(font_scale=1)
fig, (ax2) = plt.subplots(nrows = 1, ncols = 1, figsize = (8, 18))
ax2 = sns.countplot(df, y = df.municipio_nombre, order = df.municipio_nombre.value_counts().index, ax = ax2)
ax2.set(ylabel = '', title = "Municipalities")
fig.tight_layout(pad=1.0)
#plt.savefig("plant_genera_by_T6SS_type.png")
plt.show()
# Out:
# /home/javi/miniconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/javi/miniconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
from ydata_profiling import ProfileReport

from constants import CSV_DIR
datasets_names = ['desfibriladores_externos_fuera_ambito_sanitario']

for name in datasets_names:
    print(name)
    path = CSV_DIR / f'{name}.csv'
    df = pd.read_csv(path, sep=';', encoding='latin1')
    df = df.drop(["municipio_codigo", "direccion_codigo_postal", "direccion_coordenada_x", "direccion_coordenada_y", "codigo_dea"], axis=1)
    prof = ProfileReport(df, title="Profiling Report")
    prof.to_file(output_file=f'analysis-{name}.html')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# desfibriladores_externos_fuera_ambito_sanitario
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 14
#      12 df = pd.read_csv(path, sep=';', encoding='latin1')
#      13 df = df.drop(["municipio_codigo", "direccion_codigo_postal", "direccion_coordenada_x", "direccion_coordenada_y", "codigo_dea"], axis=1)
# ---> 14 prof = ProfileReport(df, title="Profiling Report")
#      15 prof.to_file(output_file=f'analysis-{name}.html')
#
# Cell In[7], line 14
#      12 df = pd.read_csv(path, sep=';', encoding='latin1')
#      13 df = df.drop(["municipio_codigo", "direccion_codigo_postal", "direccion_coordenada_x", "direccion_coordenada_y", "codigo_dea"], axis=1)
# ---> 14 prof = ProfileReport(df, title="Profiling Report")
#      15 prof.to_file(output_file=f'analysis-{name}.html')
# ...
