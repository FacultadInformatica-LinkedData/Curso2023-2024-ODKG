# %%
import pandas as pd
from pandas_profiling import ProfileReport

from constants import CSV_DIR
datasets_names = ['desfibriladores_externos_fuera_ambito_sanitario']

for name in datasets_names:
    print(name)
    path = CSV_DIR / f'{name}.csv'
    df = pd.read_csv(path, sep=';', encoding='latin1')
    prof = ProfileReport(df, title="Profiling Report")
    prof.to_file(output_file=f'analysis-{name}.html')
# Out:
# [autoreload of matplotlib.axes failed: Traceback (most recent call last):
#   File "/Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "/Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: can't apply this __setattr__ to _SubplotBaseMeta object
# ]
# [autoreload of matplotlib.pyplot failed: Traceback (most recent call last):
#   File "/Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/matplotlib/pyplot.py", line 674, in <module>
#     def rc_context(
#   File "/Users/cesarpantoja/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/matplotlib/pyplot.py", line 178, in _copy_docstring_and_deprecators
#     potential_decorator = _api.deprecation.DECORATORS.get(method)
# AttributeError: module 'matplotlib._api' has no attribute 'deprecation'
# ]
# desfibriladores_externos_fuera_ambito_sanitario
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/pandas_profiling/visualisation/context.py:81, in manage_matplotlib_context()
#      80     sns.set_style(style="white")
# ---> 81     yield
#      82 finally:
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 with self._recreate_cm():
# ---> 79     return func(*args, **kwds)
#
# File ~/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/pandas_profiling/visualisation/plot.py:328, in scatter_pairwise(config, series1, series2, x_label, y_label)
#     311 """Scatter plot (or hexbin plot) from two series
#     312
#     313 Examples:
#    (...)
#     326     A string containing (a reference to) the image
#     327 """
# --> 328 plt.xlabel(x_label)
#     329 plt.ylabel(y_label)
#
# File ~/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/matplotlib/pyplot.py:4138, in xlabel(xlabel, fontdict, labelpad, loc, **kwargs)
#    4129 @_copy_docstring_and_deprecators(Axes.set_xlabel)
#    4130 def xlabel(
#    4131     xlabel: str,
#    (...)
#    4136     **kwargs,
#    4137 ) -> Text:
# -> 4138     return gca().set_xlabel(
#    4139         xlabel, fontdict=fontdict, labelpad=labelpad, loc=loc, **kwargs
#    4140     )
#
# File ~/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/matplotlib/pyplot.py:2528, in gca()
#    2526 @_copy_docstring_and_deprecators(Figure.gca)
#    2527 def gca() -> Axes:
# -> 2528     return gcf().gca()
#
# File ~/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/matplotlib/pyplot.py:1000, in gcf()
#     999 else:
# -> 1000     return figure()
#
# File ~/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/matplotlib/pyplot.py:934, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     925     _api.warn_external(
#     926         f"More than {max_open_warning} figures have been opened. "
#     927         f"Figures created through the pyplot interface "
#    (...)
#     931         f"Consider using `matplotlib.pyplot.close()`.",
#     932         RuntimeWarning)
# --> 934 manager = new_figure_manager(
#     935     num, figsize=figsize, dpi=dpi,
#     936     facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#     937     FigureClass=FigureClass, **kwargs)
#     938 fig = manager.canvas.figure
#
# File ~/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/matplotlib/pyplot.py:464, in new_figure_manager(*args, **kwargs)
#     463 """Create a new figure manager instance."""
# --> 464 _warn_if_gui_out_of_main_thread()
#     465 return _get_backend_mod().new_figure_manager(*args, **kwargs)
#
# File ~/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/matplotlib/pyplot.py:441, in _warn_if_gui_out_of_main_thread()
#     440 warn = False
# --> 441 canvas_class = cast(type[FigureCanvasBase], _get_backend_mod().FigureCanvas)
#     442 if canvas_class.required_interactive_framework:
#
# File ~/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/matplotlib/pyplot.py:281, in _get_backend_mod()
#     280     switch_backend(rcParams._get("backend"))  # type: ignore[attr-defined]
# --> 281 return cast(type[matplotlib.backend_bases._Backend], _backend_mod)
#
# File ~/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/matplotlib/_api/__init__.py:217, in caching_module_getattr.<locals>.__getattr__(name)
#     216     return props[name].__get__(instance)
# --> 217 raise AttributeError(
#     218     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'backend_bases'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 12
#      10 df = pd.read_csv(path, sep=';', encoding='latin1')
#      11 prof = ProfileReport(df, title="Profiling Report")
# ---> 12 prof.to_file(output_file=f'analysis-{name}.html')
#
# File ~/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/typeguard/__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File ~/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/pandas_profiling/profile_report.py:309, in ProfileReport.to_file(self, output_file, silent)
#     306         self.config.html.assets_prefix = str(output_file.stem) + "_assets"
#     307     create_html_assets(self.config, output_file)
# --> 309 data = self.to_html()
#     311 if output_file.suffix != ".html":
#     312     suffix = output_file.suffix
#
# File ~/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/typeguard/__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File ~/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/pandas_profiling/profile_report.py:420, in ProfileReport.to_html(self)
#     412 def to_html(self) -> str:
#     413     """Generate and return complete template as lengthy string
#     414         for using with frameworks.
#     415
#    (...)
#     418
#     419     """
# --> 420     return self.html
#
# File ~/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/typeguard/__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File ~/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/pandas_profiling/profile_report.py:231, in ProfileReport.html(self)
#     228 @property
#     229 def html(self) -> str:
#     230     if self._html is None:
# --> 231         self._html = self._render_html()
#     232     return self._html
#
# File ~/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/typeguard/__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File ~/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/pandas_profiling/profile_report.py:339, in ProfileReport._render_html(self)
#     336 def _render_html(self) -> str:
#     337     from pandas_profiling.report.presentation.flavours import HTMLReport
# --> 339     report = self.report
#     341     with tqdm(
#     342         total=1, desc="Render HTML", disable=not self.config.progress_bar
#     343     ) as pbar:
#     344         html = HTMLReport(copy.deepcopy(report)).render(
#     345             nav=self.config.html.navbar_show,
#     346             offline=self.config.html.use_local_assets,
#    (...)
#     354             version=self.description_set["package"]["pandas_profiling_version"],
#     355         )
#
# File ~/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/typeguard/__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File ~/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/pandas_profiling/profile_report.py:225, in ProfileReport.report(self)
#     222 @property
#     223 def report(self) -> Root:
#     224     if self._report is None:
# --> 225         self._report = get_report_structure(self.config, self.description_set)
#     226     return self._report
#
# File ~/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/typeguard/__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File ~/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/pandas_profiling/profile_report.py:207, in ProfileReport.description_set(self)
#     204 @property
#     205 def description_set(self) -> Dict[str, Any]:
#     206     if self._description_set is None:
# --> 207         self._description_set = describe_df(
#     208             self.config,
#     209             self.df,
#     210             self.summarizer,
#     211             self.typeset,
#     212             self._sample,
#     213         )
#     214     return self._description_set
#
# File ~/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/pandas_profiling/model/describe.py:117, in describe(config, df, summarizer, typeset, sample)
#     113 scatter_matrix: Dict[Any, Dict[Any, Any]] = {
#     114     x: {y: None} for x, y in scatter_tasks
#     115 }
#     116 for x, y in scatter_tasks:
# --> 117     scatter_matrix[x][y] = progress(
#     118         get_scatter_plot, pbar, f"scatter {x}, {y}"
#     119     )(config, df, x, y, interval_columns)
#     121 # Table statistics
#     122 table_stats = progress(get_table_stats, pbar, "Get dataframe statistics")(
#     123     config, df, series_description
#     124 )
#
# File ~/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/pandas_profiling/utils/progress_bar.py:11, in progress.<locals>.inner(*args, **kwargs)
#       8 @wraps(fn)
#       9 def inner(*args, **kwargs) -> Any:
#      10     bar.set_postfix_str(message)
# ---> 11     ret = fn(*args, **kwargs)
#      12     bar.update()
#      13     return ret
#
# File ~/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/pandas_profiling/model/pairwise.py:31, in get_scatter_plot(config, df, x, y, continuous_variables)
#      29     else:
#      30         df_temp = df[[x, y]].dropna()
# ---> 31     return scatter_pairwise(config, df_temp[x], df_temp[y], x, y)
#      32 else:
#      33     return ""
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/contextlib.py:135, in _GeneratorContextManager.__exit__(self, type, value, traceback)
#     133     value = type()
#     134 try:
# --> 135     self.gen.throw(type, value, traceback)
#     136 except StopIteration as exc:
#     137     # Suppress StopIteration *unless* it's the same exception that
#     138     # was passed to throw().  This prevents a StopIteration
#     139     # raised inside the "with" statement from being suppressed.
#     140     return exc is not value
#
# File ~/Documents/Master de ciencie de datos en medicina/023-2024-ODKG/ODKG/lib/python3.9/site-packages/pandas_profiling/visualisation/context.py:85, in manage_matplotlib_context()
#      83 deregister_matplotlib_converters()  # revert to original unit registries
#      84 with warnings.catch_warnings():
# ---> 85     warnings.filterwarnings("ignore", category=matplotlib.cbook.mplDeprecation)
#      86     matplotlib.rcParams.update(originalRcParams)
#
# AttributeError: module 'matplotlib.cbook' has no attribute 'mplDeprecation'
